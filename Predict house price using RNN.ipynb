# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df= pd.read_csv("D:\\machine learning\\Datasets\\kc_house_data.csv")

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
#check null value
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
sns.set()
sns.displot(x=df["price"])

# %%
sns.countplot(x=df["bedrooms"])
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='count'>

# %%
#correlated to each columns
df.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
df.corr()["price"].sort_values()
# Out:
# zipcode         -0.053203
# id              -0.016762
# long             0.021626
# condition        0.036362
# yr_built         0.054012
# sqft_lot15       0.082447
# sqft_lot         0.089661
# yr_renovated     0.126434
# floors           0.256794
# waterfront       0.266369
# lat              0.307003
# bedrooms         0.308350
# sqft_basement    0.323816
# view             0.397293
# bathrooms        0.525138
# sqft_living15    0.585379
# sqft_above       0.605567
# grade            0.667434
# sqft_living      0.702035
# price            1.000000
# Name: price, dtype: float64

# %%
#here we see sqft_living is highlly correlatd to price so
sns.scatterplot(x="price", y="sqft_living", data=df)
plt.show()

# %%
sns.boxplot(x="bedrooms", y="price", data=df)
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='price'>

# %%
sns.scatterplot(x="price", y="long", data= df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='long'>

# %%
sns.scatterplot(x="price", y="lat", data= df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='lat'>

# %%
sns.scatterplot(x="long", y="lat", data= df, hue="price")
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
len(df[df["price"]>2000000])
# Out:
# 198

# %%
df.sort_values("price", ascending=False).head(20)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 7252   6762700020  20141013T000000  7700000.0         6       8.00
# 3914   9808700762  20140611T000000  7062500.0         5       4.50
# 9254   9208900037  20140919T000000  6885000.0         6       7.75
# 4411   2470100110  20140804T000000  5570000.0         5       5.75
# 1448   8907500070  20150413T000000  5350000.0         5       5.00
# 1315   7558700030  20150413T000000  5300000.0         6       6.00
# 1164   1247600105  20141020T000000  5110800.0         5       5.25
# 8092   1924059029  20140617T000000  4668000.0         5       6.75
# 2626   7738500731  20140815T000000  4500000.0         5       5.50
# 8638   3835500195  20140618T000000  4489000.0         4       3.00
# 12370  6065300370  20150506T000000  4208000.0         5       6.00
# 4149   6447300265  20141014T000000  4000000.0         4       5.50
# 2085   8106100105  20141114T000000  3850000.0         4       4.25
# ...

# %%
#create a new data set which house price is less then 2000000
new_df= df.sort_values("price", ascending=False).iloc[198:]
new_df.head()
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 13271  2524049318  20140528T000000  2000000.0         4       3.00
# 21     2524049179  20140826T000000  2000000.0         3       2.75
# 10468  1732800310  20150302T000000  2000000.0         4       3.75
# 15039  2726049034  20141110T000000  2000000.0         3       3.25
# 19215  4131900042  20140516T000000  2000000.0         5       4.25
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 13271         4260     18000     2.0           0     2  ...     11
# 21            3050     44867     1.0           0     4  ...      9
# 10468         2870      4500     2.0           0     3  ...     10
# 15039         2610     16387     2.0           1     4  ...      9
# 19215         6490     10862     2.0           0     3  ...     11
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 13271        4260              0      2000             0    98040  47.5355
# ...

# %%
sns.scatterplot(x="long", y="lat", data= new_df, hue="price", ec=None, alpha=.3, palette="RdYlGn")
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
#feature engineering

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
#in ID coloum there is no need to our analysis so we can delete this column
df= df.drop("id", axis=1)

# %%
df["date"]
# Out:
# 0        20141013T000000
# 1        20141209T000000
# 2        20150225T000000
# 3        20141209T000000
# 4        20150218T000000
#               ...
# 21608    20140521T000000
# 21609    20150223T000000
# 21610    20140623T000000
# 21611    20150116T000000
# 21612    20141015T000000
# Name: date, Length: 21613, dtype: object

# %%
df["year"]= df["date"].str[:4]
df["month"]= df["date"].str[4:6]
df["dates"]= df["date"].str[6:8]

# %%
#i already extract date colum value so date column is no requred more
df= df.drop("date", axis=1)

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  ...  yr_built  yr_renovated  zipcode      lat  \
# 0     0          3      7  ...      1955             0    98178  47.5112
# 1     0          3      7  ...      1951          1991    98125  47.7210
# 2     0          3      6  ...      1933             0    98028  47.7379
# 3     0          5      7  ...      1965             0    98136  47.5208
# 4     0          3      8  ...      1987             0    98074  47.6168
#
#       long  sqft_living15  sqft_lot15  year  month dates
# ...

# %%
sns.boxplot(x="month", y="price", data=df)
# Out:
# <AxesSubplot:xlabel='month', ylabel='price'>

# %%
df.groupby("month").mean()["price"].plot()
# Out:
# <AxesSubplot:xlabel='month'>

# %%
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'year', 'month', 'dates'],
#       dtype='object')

# %%
df["zipcode"].value_counts()
#here zipcode is a continus value, total 70 zeepcode here, if we convert it in demi veriable it takes 70
# more columns, it can be divided in some categoti but it is complex and doing it manually
#so i will delete zipcode beacuse we have  value lattitude and lamptitude
# Out:
# 98103    602
# 98038    590
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    105
# 98010    100
# 98024     81
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64

# %%
df= df.drop(["zipcode"], axis=1)

# %%
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'year', 'month', 'dates'],
#       dtype='object')

# %%
df["sqft_basement"].value_counts()
#here we see there are also continus value but large size of data is 0, so we are luky here beacuse of zero
#in future i need to learn more details about feature engineering
# Out:
# 0      13126
# 600      221
# 700      218
# 500      214
# 800      206
#        ...
# 518        1
# 374        1
# 784        1
# 906        1
# 248        1
# Name: sqft_basement, Length: 306, dtype: int64

# %%
df["yr_renovated"].value_counts()
#here is same case, we consider this value renovated or not renovated
# Out:
# 0       20699
# 2014       91
# 2013       37
# 2003       36
# 2005       35
#         ...
# 1951        1
# 1959        1
# 1948        1
# 1954        1
# 1944        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
#create model

# %%
X= df.drop("price", axis=1).values
y= df["price"].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler= MinMaxScaler()
X_train
# Out:
# array([[3, 2.5, 1920, ..., '2015', '02', '18'],
#        [4, 2.5, 2620, ..., '2014', '07', '08'],
#        [3, 2.5, 1590, ..., '2014', '08', '19'],
#        ...,
#        [3, 2.25, 1780, ..., '2014', '10', '29'],
#        [2, 1.0, 1150, ..., '2014', '09', '11'],
#        [3, 1.0, 1450, ..., '2015', '03', '12']], dtype=object)

# %%
X_train= scaler.fit_transform(X_train)
X_train
# Out:
# array([[0.27272727, 0.3125    , 0.12301887, ..., 1.        , 0.09090909,
#         0.56666667],
#        [0.36363636, 0.3125    , 0.17584906, ..., 0.        , 0.54545455,
#         0.23333333],
#        [0.27272727, 0.3125    , 0.09811321, ..., 0.        , 0.63636364,
#         0.6       ],
#        ...,
#        [0.27272727, 0.28125   , 0.11245283, ..., 0.        , 0.81818182,
#         0.93333333],
#        [0.18181818, 0.125     , 0.06490566, ..., 0.        , 0.72727273,
#         0.33333333],
#        [0.27272727, 0.125     , 0.08754717, ..., 1.        , 0.18181818,
#         0.36666667]])

# %%
X_test= scaler.fit_transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
X_train.shape
# Out:
# (15129, 20)

# %%
model= Sequential()
model.add(Dense(20, activation="relu"))
model.add(Dense(20, activation="relu"))
model.add(Dense(20, activation="relu"))
model.add(Dense(20, activation="relu"))
model.add(Dense(20, activation="relu"))
model.add(Dense(1))

model.compile(optimizer="adam", loss="mse")

# %%
model.fit(x= X_train, y=y_train, validation_data=(X_test, y_test), batch_size= 124, epochs=200)
# Out:
# Epoch 1/200
# 123/123 [==============================] - 1s 4ms/step - loss: 423610679296.0000 - val_loss: 432882483200.0000
# Epoch 2/200
# 123/123 [==============================] - 0s 2ms/step - loss: 416433373184.0000 - val_loss: 403001442304.0000
# Epoch 3/200
# 123/123 [==============================] - 0s 2ms/step - loss: 273123835904.0000 - val_loss: 133966184448.0000
# Epoch 4/200
# 123/123 [==============================] - 0s 2ms/step - loss: 104186978304.0000 - val_loss: 104369840128.0000
# Epoch 5/200
# 123/123 [==============================] - 0s 2ms/step - loss: 99408822272.0000 - val_loss: 101740486656.0000
# Epoch 6/200
# 123/123 [==============================] - 0s 2ms/step - loss: 96813867008.0000 - val_loss: 98174124032.0000
# Epoch 7/200
# 123/123 [==============================] - 0s 2ms/step - loss: 94039613440.0000 - val_loss: 94699102208.0000
# Epoch 8/200
# ...

# %%
losses= pd.DataFrame(model.history.history)
losses.plot()
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, explained_variance_score

# %%
prediction= model.predict(X_test)
# Out:
# 203/203 [==============================] - 0s 1ms/step

# %%
mean_absolute_error(y_test, prediction)
# Out:
# 128049.18178472572

# %%
np.sqrt(mean_squared_error(y_test, prediction))
# Out:
# 193974.54400379982

# %%
explained_variance_score(y_test, prediction)
# Out:
# 0.7472328746583847

# %%
plt.scatter(y_test, prediction)
plt.plot(y_test, y_test, "r")

# %%
single_house= df.drop("price", axis=1).iloc[0]
single_house
# Out:
# bedrooms               3
# bathrooms            1.0
# sqft_living         1180
# sqft_lot            5650
# floors               1.0
# waterfront             0
# view                   0
# condition              3
# grade                  7
# sqft_above          1180
# sqft_basement          0
# yr_built            1955
# yr_renovated           0
# lat              47.5112
# long            -122.257
# sqft_living15       1340
# sqft_lot15          5650
# year                2014
# month                 10
# dates                 13
# Name: 0, dtype: object

# %%
single_house= scaler.transform(single_house.values.reshape(-1, 20))
single_house
# Out:
# array([[0.09090909, 0.06896552, 0.08508403, 0.00470372, 0.        ,
#         0.        , 0.        , 0.5       , 0.33333333, 0.09540636,
#         0.        , 0.47826087, 0.        , 0.56914119, 0.21374686,
#         0.16510319, 0.01183711, 0.        , 0.81818182, 0.4       ]])

# %%
model.predict(single_house)
# Out:
# 1/1 [==============================] - 0s 18ms/step
# array([[209758.33]], dtype=float32)

# %%
df.head(1)
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3        1.0         1180      5650     1.0           0
#
#    view  condition  grade  ...  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7  ...              0      1955             0
#
#        lat     long  sqft_living15  sqft_lot15  year month dates
# 0  47.5112 -122.257           1340        5650  2014    10    13
#
# [1 rows x 21 columns]
